# %% [markdown]
# <a href="https://colab.research.google.com/github/j-see17/Action-Learning-Project/blob/main/776_VML_Coding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("campaign_deployments_clean.csv")

# Basic normalize
df.columns = [c.strip() for c in df.columns]
df['Launch Date'] = pd.to_datetime(df['Launch Date'], errors='coerce')
df['Deploy_Status'] = df['Deploy_Status'].str.strip().str.title()

# Normalize Type and Channel
df['Type'] = df['Type'].str.strip().str.title()
df['Channel'] = df['Channel'].str.strip().str.upper()

# Normalize Priority (e.g., P2 - High -> Priority_Level = 2,  High)
df['Priority_Level'] = df['Priority'].str.extract(r'P(\d+)').astype(int)

# Optional: split Size/T-Shirt if encoded
# Example: "LOther - L2" -> Size_Category = "L", Size_Number = 2
import numpy as np
def split_size(s):
    if pd.isna(s): return pd.Series([np.nan, np.nan])
    m = re.search(r'([A-Z])(\d+)$', s)
    return pd.Series([m.group(1) if m else np.nan, int(m.group(2)) if m else np.nan])

df[['Size_Category','Size_Number']] = df['Size'].apply(split_size)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2107184385.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("campaign_deployments_clean.csv")
#       4
#       5 # Basic normalize
#
# ...

# %%
# Install the python-pptx library if it's not already installed
# !pip install python-pptx

from pptx import Presentation

prs = Presentation()
title_slide_layout = prs.slide_layouts[0]
slide = prs.slides.add_slide(title_slide_layout)
title = slide.shapes.title
subtitle = slide.placeholders[1]

title.text = "Hello, World!"
subtitle.text = "python-pptx was here!"

prs.save('test.pptx')

# %%
# 1 import library
from pptx import Presentation

# 2 create presentation
presentation = Presentation()
# 3 create slide
# 3.1 layout section
slide_layout = presentation.slide_layouts[1] # title and content layout
# 3.2 slide creation
slide = presentation.slides.add_slide(slide_layout)
# 4 add title
slide.placeholders[0].text = "My Title"
# 5 add content
slide.placeholders[1].text = "Hello World/nBye"
# 6 save presentation
presentation.save("test.pptx")
